# %%
from Task import Draw

# %%
filename = 'deviation.json'
paths = Draw.draw_plots(filename)
# Out:
# gt_corners save to plots/gt_corners
# rb_corners save to plots/rb_corners
# compare save to plots/compare

# %%
paths
# Out:
# ['plots/gt_corners', 'plots/rb_corners', 'plots/compare']

# %%
Draw.show_plot(paths[0])

# %%
Draw.show_plot(paths[1])

# %%
Draw.show_plot(paths[2])
